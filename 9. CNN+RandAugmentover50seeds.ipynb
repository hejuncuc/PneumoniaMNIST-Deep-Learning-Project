# %% [markdown]
# In this project, we will work with the medical mnist datasource, specifically the pneumonia dataset from https://medmnist.com/ . The problem consists of classifying chest x-ray images as having pneumonia or not. Run the below lines of code to install the appropriate dataloaders and visualize the data

# %%
# !pip install -qqq medmnist

# %%
from tqdm import tqdm
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.data as data
import torchvision.models as models
import torchvision.transforms as transforms

import medmnist
from medmnist import INFO, Evaluator
from numpy.random import RandomState
import numpy as np
import torch
import torch.optim as optim
from torch.utils.data import Subset
import re
from torchvision import datasets, transforms

# %% [markdown]
# *** Challenge 1***

# %% [markdown]
# Here the goal is to train on 10 samples on the pneumonia mnist data. In this preliminary testbed, the evaluation will be done on a 1000 sample randomly sampled development set. Note in the end the final evaluation will be done on the full Pneumoniamnist test set as well as potentially a separate dataset. The development set samples here thus should not be used for training in any way, the final evaluation will provide only 10 random samples of the same distribution and as well to evaluate the generality of your algorithm from a data source that is not the Pneumoniamnist training data.

# %% [markdown]
# Feel free to modify this testbed to your liking, including the normalization transformations, etc. Note, however, the final evaluation testbed will have a rigid set of components where you will need to place your answer. The only constraint is the data. Refer to the full project instructions for more information.

# %% [markdown]
# Below we set up training functions. Again you are free to fully modify this testbed in your prototyping within the constraints of the data used. You can use tools outside of PyTorch for training models if desired as well although the torchvision dataloaders will still be useful for interacting with the Pneumoniamnist dataset.

# %%
def train(model, device, train_loader, optimizer, epoch, display=True):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.binary_cross_entropy_with_logits(output, target.float())
        loss.backward()
        optimizer.step()
    if display:
      print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
          epoch, batch_idx * len(data), len(train_loader.dataset),
          100. * batch_idx / len(train_loader), loss.item()))
    return loss.item()

def test(model, device, test_loader, name="\nVal"):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.binary_cross_entropy_with_logits(output, target.float(), size_average=False).item() # sum up batch loss
            pred = output >= 0.5 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    print('{} set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return 100. * correct / len(test_loader.dataset)

# %% [markdown]
# The below tries 5 random problem instances. Due to the small sample size, the variance of this problem is quite high. Run several instances of the problem to reduce the variance.

# %% [markdown]
# Resnet18 + RandAugment + HyperTuned parameters

# %%
import torch
import torch.nn as nn 
import torch.nn.functional as F

class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.layers = nn.ModuleList()
        
        self.layers+=[nn.Conv2d(1, 16,  kernel_size=3) , 
                      nn.ReLU(inplace=True)]
        self.layers+=[nn.Conv2d(16, 16,  kernel_size=3, stride=2), 
                      nn.ReLU(inplace=True)]
        self.layers+=[nn.Conv2d(16, 32,  kernel_size=3), 
                      nn.ReLU(inplace=True)]
        self.layers+=[nn.Conv2d(32, 32,  kernel_size=3, stride=2), 
                      nn.ReLU(inplace=True)]
        self.fc = nn.Linear(32*4*4, 1)
    def forward(self, x):
        for i in range(len(self.layers)):
          x = self.layers[i](x)
        x = x.view(-1, 32*4*4)
        x = self.fc(x)
        return x

# %%
# %%time
from torchvision.transforms.autoaugment import RandAugment

torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
random.seed(0)
np.random.seed(0)

# preprocessing
data_flag = 'pneumoniamnist'

download = True

info = INFO[data_flag]
n_classes = len(info['label'])
DataClass = getattr(medmnist, info['python_class'])

trn_transform = transforms.Compose([transforms.RandAugment(),
                                     transforms.ToTensor(),
                                     transforms.Normalize(mean=[.5], std=[.5])])

val_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize(mean=[.5], std=[.5])])

use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# load the data
train_dataset = DataClass(split='train', transform=trn_transform, download=download)
val_dataset = DataClass(split='train', transform=val_transform, download=download)

accs_val = []

for seed in  range(0, 50):
  prng = RandomState(seed)
  random_permute = prng.permutation(np.arange(0, 1000))
  train_top = 10//n_classes
  val_top = 1000//n_classes
  indx_train = np.concatenate([np.where(train_dataset.labels == label)[0][random_permute[0:train_top]] for label in range(0, n_classes)])
  indx_val = np.concatenate([np.where(train_dataset.labels == label)[0][random_permute[train_top:train_top + val_top]] for label in range(0, n_classes)])

  train_data = Subset(train_dataset, indx_train)
  val_data = Subset(val_dataset, indx_val)

  print('Num Samples For Training %d Num Samples For Val %d'%(train_data.indices.shape[0],val_data.indices.shape[0]))

  train_loader = torch.utils.data.DataLoader(train_data,
                                             batch_size=32, 
                                             shuffle=True)

  val_loader = torch.utils.data.DataLoader(val_data,
                                             batch_size=128, 
                                             shuffle=False)

  model = Net()
  model.to(device)

  optimizer = torch.optim.AdamW(model.parameters(),lr=1e-3)

  for epoch in range(50):
    train(model, device, train_loader, optimizer, epoch, display=epoch%5==0)
  accs_val.append(test(model, device, val_loader))

accs_val = np.array(accs_val)

print('Val acc over 5 instances on dataset: %s %.2f +- %.2f (var: %.2f)'%(data_flag, accs_val.mean(), accs_val.std(), accs_val.var()))
# Out:
# Using downloaded and verified file: /root/.medmnist/pneumoniamnist.npz
# Using downloaded and verified file: /root/.medmnist/pneumoniamnist.npz
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.693472
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.687650
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.681289
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.657084
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.565002
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.554027
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.549567
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.596566
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.331854
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.343588
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Val set: Average loss: 0.3539, Accuracy: 825/1000 (82.50%)
#
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.692776
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.688006
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.686682
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.671028
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.657836
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.636825
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.523373
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.424235
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.307852
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.306911
#
# Val set: Average loss: 0.8853, Accuracy: 604/1000 (60.40%)
#
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.693384
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.689055
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.691973
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.647254
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.645449
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.542860
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.306233
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.427604
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.345016
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.220592
#
# Val set: Average loss: 0.4807, Accuracy: 789/1000 (78.90%)
#
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.693461
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.691529
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.685449
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.654792
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.650470
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.583551
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.670854
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.539099
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.381005
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.422142
#
# Val set: Average loss: 0.6317, Accuracy: 649/1000 (64.90%)
#
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.692983
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.680884
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.660456
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.601341
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.594134
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.554632
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.967751
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.356525
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.482433
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.397678
#
# Val set: Average loss: 0.4437, Accuracy: 780/1000 (78.00%)
#
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.692341
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.685231
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.678326
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.669275
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.642835
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.626880
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.495673
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.412186
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.203645
# Train Epoch: 45 [0/10 (0%)]	Loss: 0
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.319868
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.322968
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.192529
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.288030
#
# Val set: Average loss: 0.3965, Accuracy: 766/1000 (76.60%)
#
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.693783
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.689374
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.691369
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.655656
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.639140
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.581174
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.547499
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.485598
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.342656
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.192888
#
# Val set: Average loss: 0.6045, Accuracy: 694/1000 (69.40%)
#
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.694265
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.684627
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.681975
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.635212
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.573390
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.513566
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.545795
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.627576
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.713215
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.440065
#
# Val set: Average loss: 0.4993, Accuracy: 760/1000 (76.00%)
#
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.694067
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.688552
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.660206
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.658226
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.597816
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.531437
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.635843
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.325329
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.880810
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.474240
#
# Val set: Average loss: 0.4048, Accuracy: 811/1000 (81.10%)
#
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.691952
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.680439
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.666188
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.663207
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.496708
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.572965
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.662798
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.601065
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.549791
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.210583
#
# Val set: Average loss: 0.4351, Accuracy: 782/1000 (78.20%)
#
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.693238
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.691074
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.685866
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.689423
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.661630
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.616552
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.628268
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.637923
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.629179
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.449868
#
# Val set: Average loss: 0.4054, Accuracy: 807/1000 (80.70%)
#
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.694476
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.682097
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.671190
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.632514
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.607771
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.546625
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.296125
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.117559
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.216342
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.310338
#
# Val set: Average loss: 0.4082, Accuracy: 819/1000 (81.90%)
#
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.694521
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.682746
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.661058
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.564405
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.426982
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.361553
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.375224
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.100430
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.326611
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.206359
#
# Val set: Average loss: 0.3737, Accuracy: 819/1000 (81.90%)
#
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.694023
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.691264
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.684750
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.684953
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.663162
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.618952
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.742841
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.460163
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.487259
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.695874
#
# Val set: Average loss: 0.5286, Accuracy: 672/1000 (67.20%)
#
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.692118
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.686607
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.666080
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.649679
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.504828
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.433760
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.403133
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.410662
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.559445
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.598033
#
# Val set: Average loss: 0.8515, Accuracy: 642/1000 (64.20%)
#
# Num Samples For Training 10 Num Samples For Val 1000
# Train Epoch: 0 [0/10 (0%)]	Loss: 0.695080
# Train Epoch: 5 [0/10 (0%)]	Loss: 0.692956
# Train Epoch: 10 [0/10 (0%)]	Loss: 0.689954
# Train Epoch: 15 [0/10 (0%)]	Loss: 0.690234
# Train Epoch: 20 [0/10 (0%)]	Loss: 0.673964
# Train Epoch: 25 [0/10 (0%)]	Loss: 0.648060
# Train Epoch: 30 [0/10 (0%)]	Loss: 0.616383
# Train Epoch: 35 [0/10 (0%)]	Loss: 0.619993
# Train Epoch: 40 [0/10 (0%)]	Loss: 0.543030
# Train Epoch: 45 [0/10 (0%)]	Loss: 0.607010
#
# Val set: Average loss: 0.5134, Accuracy: 832/1000 (83.20%)
#
# Val acc over 5 instances on dataset: pneumoniamnist 77.48 +- 8.11 (var: 65.73)
# CPU times: user 37.1 s, sys: 1.44 s, total: 38.5 s
# Wall time: 40.6 s

# %%
import matplotlib.pyplot as plt

plt.plot(accs_val)
plt.xlabel('seeds')
plt.ylabel('accuracy')
plt.title('Validation set over 50 seeds for CNN');
plt.savefig('C1val50seeds_CNN_hyperparam.png')
